# %% [markdown]
# ## Nafisa Mostofa, Problem 2

# %%
# %matplotlib inline
import matplotlib as mpl
import matplotlib.pyplot as plt
from mpl_toolkits import mplot3d
import numpy as np

# %%
import numpy as np
np.random.seed(42)

x1 = 2 * np.random.rand(100, 1)
x2 = 10 * np.random.rand(100, 1)
ys = 4 + 3 * x1 + 3 * x2 + np.random.rand(100,1)

# %%
fig=plt.figure(1)
ax = fig.add_subplot(111, projection='3d')
ax.scatter(x2, x1, ys, color='y')
ax.set_xlabel('x2')
ax.set_ylabel('x1')
ax.set_zlabel('y')
# Out:
# Text(0.5, 0, 'y')

# %%
# split the data into training and test sets
# train set
train_x1 = x1[:80]
train_x2 = x2[:80]
train_ys = ys[:80]
# test set
test_x1 = x1[80:]
test_x2 = x2[80:]
test_ys = ys[80:]

print("1",train_x1[0])
print("2",train_x2[0])
print("3",train_ys[0])
# Out:
# 1 [0.74908024]
# 2 [0.31429186]
# 3 [7.83214793]

# %% [markdown]
# # Linear regression using numpy

# %%
# number of epochs
epochs = 10
# learning rate
lr = 0.01

# %%
# initial value for weight w and bias b
w1 = np.random.randn(1)
w2 = np.random.randn(1)
b = np.zeros(1)

# %%
for epoch in np.arange(epochs):
  for i in np.arange(80):
    y_pred = w1 * train_x1[i] + w2 * train_x2[i] + b
    
    grad_w1 = (y_pred - train_ys[i]) * train_x1[i]
    grad_w2 = (y_pred - train_ys[i]) * train_x2[i]
    grad_b = (y_pred - train_ys[i])
    
    w1 -= lr * grad_w1
    w2 -= lr *grad_w2
    b -= lr * grad_b

# %%
test_loss = 0
for i in np.arange(20):
  test_loss += 0.5 * (w2 * test_x2[i] + w1 * test_x1[i] + b - test_ys[i]) ** 2
test_loss /= 20

# %%
test_loss
# Out:
# array([0.0858038])

# %%
pred_ys = w1 * test_x1 + w2 * test_x2 + b

# %%
fig=plt.figure(2)
ax = fig.add_subplot(111, projection='3d')
zdata = pred_ys
x1_data = test_x1
x2_data = test_xt
ax.set_xlabel('x2')
ax.set_ylabel('x1')
ax.set_zlabel('y')


ax.scatter(x2_data, x1_data, test_ys, color='r')
ax.scatter(x2_data, x1_data, pred_ys, color='b')

# %%
b
# Out:
# array([3.96211813])

# %%
w1
# Out:
# array([3.28269761])

# %%
w2
# Out:
# array([3.06985138])
